# %% [markdown]
# # Практика №4

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from numpy import tan

# %% [markdown]
# ## 1. Используйте функцию и отрезок ([a, b]) из вашего варианта задания 2 (которые вы использовали для интегрирования). Разбейте отрезок на столько частей, сколько считаете нужным. Вычислите значение функции для всех точек получившегося массива.

# %%
a, b = 4, 6


def function(x):
    return 2 / tan(x)


step = (b - a) / 50
points = []
results = []
while a <= b:
    points.append(a)
    results.append(function(a))
    a += step

# %%
x=points
y=results

# %% [markdown]
# 2. Используя множество точек и множество значений функции в этих
# точках, постройте простой график функции (метод plot()). Задайте
# графику название. Подпишите оси. Установите желаемые размеры
# шрифта для названия и подписей. Добавьте на график легенду.

# %%
def second_task(x, y):
    matplotlib.rcParams['font.family'] = 'Times New Roman'#шрифт
    plt.title('Моя функция:',fontsize=15)#Заголовок
    plt.plot(x,y)#оси
    
    plt.rc('font', size=8)#Размер шрифта
    plt.rc('axes', titlesize=10)#Размер подписи
    plt.rc('axes', labelsize=10)#Размер значения
    plt.rc('legend', fontsize=12)#Размер шрифта легенды
    
    
    plt.legend(['y = 2 / tan(x)'])
    plt.ylabel('y')
    plt.xlabel('x')
    
    plt.show()
second_task(x, y)

# %% [markdown]
# 3. Постройте точечный график функции, в качестве меток для точек
# используйте любой любой доступный маркер (доступные маркеры
# смотрите здесь). Задайте графику название. Подпишите оси. Измените
# цвет точек на желаемый. Цвет задайте с помощью указания значений
# красного, зеленого и синего (по модели RGB). Добавьте на график сетку.
# Укажите цвет и непрозрачность линий сетки.

# %%
def third_task(x, y):
    plt.plot(x, y, marker="o", markerfacecolor=[0, 0, 1, 1], markersize=8)
    plt.title("Моя функция:", fontsize=15)
    plt.grid(
        color=([0.3, 0.2, 1]), linestyle="-", linewidth=0.3, alpha=0.5
    )  # параметры сетки

    plt.ylabel("y")
    plt.xlabel("x")

    plt.show()


third_task(x, y)

# %% [markdown]
# 4. Используйте выборки из равномерного и нормального распределения
# (из задания 3). Постройте две гистограммы. Используйте различные
# цвета для гистограмм. Установите для каждой гистограммы собственное
# значение количества разбиений. Подпишите гистограммы.

# %%
from scipy import stats
def fourth_task_old():
    sample_one = stats.norm.rvs(size=100)
    sample_two = stats.uniform.rvs(size=100)
    return sample_one, sample_two

# %%
sample_norm, sample_uniform = fourth_task_old()

# %%
def fourt_task_old(sample_norm, sample_uniform):
    fig, axs = plt.subplots(1, 2, figsize=(9, 3), sharey=True, sharex=True)#Общая ось

    axs[0].hist(sample_norm, bins=40, color="blue")
    axs[0].set_title("Нормальное")

    axs[1].hist(sample_uniform, bins=50, color="green")
    axs[1].set_title("Равномерное")

    plt.show()


fourt_task_old(sample_norm, sample_uniform)

# %% [markdown]
# 5. Сгенерируйте выборку из равномерного распределения, состоящую из
# 50 целых чисел от 1 до 5 (не включая 5). Посчитайте, сколько раз
# встречается каждое из чисел в выборке (без циклов!). На основе
# полученной информации постройте круговую и столбчатую диаграммы.
# Подпишите диаграммы. Для круговой диаграммы укажите подписи
# секторов. Для столбчатой диаграммы укажите подписи столбцов. Для
# обеих диаграмм укажите множество используемых цветов (для
# раскраски секторов и столбцов).

# %%
def fifth_task():
    fig, axs = plt.subplots(1, 2, figsize=(9, 3))
    
    sample =  np.random.randint(1, 5, size=50)
    count_numbers = np.bincount(sample)
    axs[0].pie(count_numbers[1:], labels=['1', '2', '3', '4'], colors=['yellow','red','green','blue'], autopct='%1.1f%%')
    axs[0].set_title('Круговая диаграмма  ')
    
    axs[1].bar(['1', '2', '3', '4'], count_numbers[1:], color=['yellow','red','green','blue'])
    axs[1].set_title('Столбчатая диаграмма  ');
    
    plt.show()

fifth_task()

# %% [markdown]
# 6. Используя знания о разбиении отрезка на множество точек (из пункта
# 1), а также функцию с несколькими переменными из задания 2 (которая
# использовалась для решения задачи оптимизации), постройте
# трехмерный график функции. Установите цвет линии на графике.
# Важно: если в вашем варианте к заданию 2 функция состояла более чем
# из двух переменных - используйте только первые две переменные.

# %%
def sixth_task():
    def func(x, y):
            return (x-1.5)**2+(y-2)**2
    
    x = np.random.random(5)
    y = np.random.random(5)
    
    fig = plt.figure()#контейнер с фигурой
    ax = fig.add_subplot(111, projection='3d')
    ax.plot(x,y, func(x,y), color=[0, 0, 1, 1])
    
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('f(x)')
    ax.set_title('Трехмерный график')
    
    plt.show()

sixth_task()

# %% [markdown]
# 7. Используя подграфики (subplots) постройте сетку 2x2 из 4 графиков.
# Установите размер сетки. Добавьте заголовок сетки, укажите размер
# шрифта. В левом верхнем углу сетки разместите график из пункта 2
# текущего задания, в правом верхнем - из пункта 3. В левом нижнем -
# круговую диаграмму из пункта 5. В правом нижнем - трехмерный
# график из пункта 6. Для любого из графиков установите цвет фона.

# %%
def seventh_task(style='default'):

    plt.style.use(style)
    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Задание 7", size=20)
#///////////////////////////////////////////////////////////////////////////////////////////
    ax1 = fig.add_subplot(2, 2, 1)

    def second_task_for_seventh(ax):
        ax.set_title('Задание 2', fontsize=15)
        ax.set_xlabel('x')
        ax.set_ylabel('y')
        ax.plot(x, y)
        return ax
        
    ax1 = second_task_for_seventh(ax1)
#///////////////////////////////////////////////////////////////////////////////////////////
    ax2 = fig.add_subplot(2, 2, 2)

    def third_task_for_seventh(ax):
        ax.plot(x, y,marker='o', markerfacecolor=[0, 0, 1, 1], markersize=8)
        ax.set_title('Задание 3',fontsize=15)
        ax.grid(color=([0.3,0.2,1]), linestyle='-', linewidth=0.3, alpha=0.5)
        ax.set_ylabel('y')
        ax.set_xlabel('x')
        ax.set_facecolor('yellow')

        return ax
  
    ax2 = third_task_for_seventh(ax2)
#///////////////////////////////////////////////////////////////////////////////////////////
    ax3 = fig.add_subplot(2,2,3)

    def fifth_task_for_seventh(ax):
        sample =  np.random.randint(1, 5, size=50)
        count_numbers = np.bincount(sample)
        ax.pie(count_numbers[1:], labels=['1', '2', '3', '4'], colors=['yellow','red','green','blue'], autopct='%1.1f%%', startangle=140)
        ax.set_title('Круговая диаграмма', fontsize=15)

    ax3 = fifth_task_for_seventh(ax3)
#///////////////////////////////////////////////////////////////////////////////////////////
    ax4 = fig.add_subplot(2,2,4, projection='3d')
    
    def sixth_task_for_seventh(ax):
        def func(x, y):
                return (x-1.5)**2+(y-2)**2
        
        x = np.random.random(5)
        y = np.random.random(5)

        ax.plot(x,y, func(x,y), color=[0, 0, 1, 1])
        
        ax.set_xlabel('x')
        ax.set_ylabel('y')
        ax.set_zlabel('f(x)')
        ax.set_title('Трехмерный график', fontsize=15)
        return ax
    
    ax4 = sixth_task_for_seventh(ax4)
#///////////////////////////////////////////////////////////////////////////////////////////
    plt.show()

seventh_task()

# %% [markdown]
# 8. Посмотрите доступные в pyplot стили оформления графиков.
# Попробуйте 3 любых стиля на ваш выбор. Для каждого стиля:
# установите его, отобразите сетку графиков из пункта 7. Таким образом,
# всего за это задание сетка из 4 графиков должна быть отображена 4 раза.
# Замечание: если установка стиля не изменяет внешнего вида графика -
# не расстраивайтесь. Многие стили предназначены для установки
# цветовой палитры, а по заданию вы сами устанавливали цвета. Если не
# видите изменений - просто переходите к следующему стилю.

# %%
def eight_task():
    seventh_task('grayscale')
    seventh_task('dark_background')
    seventh_task('Solarize_Light2')

eight_task()
plt.style.use('default')
